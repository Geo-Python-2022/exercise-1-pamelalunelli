# %%
import math

# %%
ice_cream_rating = 7

# %%
sleeping_rating = 8

# %%
first_name = input('What is your first name?')
# Out:
# What is your first name? Pâmela

# %%
last_name = input('What is your last name?')
# Out:
# What is your last name? Lunelli

# %%
my_name = first_name + " " + last_name
print(my_name)
# Out:
# Pâmela Lunelli

# %%
hapiness_rating = (ice_cream_rating + sleeping_rating)/2
print(hapiness_rating)
# Out:
# 7.5

# %%
type(hapiness_rating)
# Out:
# float

# %%
type(ice_cream_rating)
# Out:
# int

# %%
type(sleeping_rating)
# Out:
# int

# %% [markdown]
# Did all of the data types make sense?
# Yes.
# Were there any data types that were different than you expected?
# No.

# %%
print('My name is', first_name, 'and I give eating ice cream a score of', ice_cream_rating, ' out of 10!')
# Out:
# My name is Pâmela and I give eating ice cream a score of 7  out of 10!

# %%
print('I am', my_name, 'and my sleeping enjoyment rating is', sleeping_rating ,' / 10!')
# Out:
# I am Pâmela Lunelli and my sleeping enjoyment rating is 8  / 10!

# %%
print('Based on the factors above, my happiness rating is', hapiness_rating, 'out of 10, or', (hapiness_rating/10)*100 ,'%!')
# Out:
# Based on the factors above, my happiness rating is 7.5 out of 10, or 75.0 %!
